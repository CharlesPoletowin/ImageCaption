# %%
# !git clone https://github.com/CharlesPoletowin/ImageCaption.git
# Out:
# Cloning into 'ImageCaption'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 9 (delta 1), reused 9 (delta 1), pack-reused 0
# Unpacking objects: 100% (9/9), done.

# %%
import os
os.chdir("ImageCaption")

# %%
# !mkdir data
# !wget http://msvocds.blob.core.windows.net/annotations-1-0-3/captions_train-val2014.zip -P ./data/
# !wget http://msvocds.blob.core.windows.net/coco2014/train2014.zip -P ./data/
# !wget http://msvocds.blob.core.windows.net/coco2014/val2014.zip -P ./data/

# !unzip ./data/captions_train-val2014.zip -d ./data/
# !rm ./data/captions_train-val2014.zip
# !unzip ./data/train2014.zip -d ./data/
# !rm ./data/train2014.zip 
# !unzip ./data/val2014.zip -d ./data/ 
# !rm ./data/val2014.zip
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# !python build_vocab.py
# Out:
# loading annotations into memory...
# Done (t=0.67s)
# creating index...
# index created!
# [0/414113] Tokenized the captions.
# [1000/414113] Tokenized the captions.
# [2000/414113] Tokenized the captions.
# [3000/414113] Tokenized the captions.
# [4000/414113] Tokenized the captions.
# [5000/414113] Tokenized the captions.
# [6000/414113] Tokenized the captions.
# [7000/414113] Tokenized the captions.
# [8000/414113] Tokenized the captions.
# [9000/414113] Tokenized the captions.
# [10000/414113] Tokenized the captions.
# [11000/414113] Tokenized the captions.
# [12000/414113] Tokenized the captions.
# [13000/414113] Tokenized the captions.
# [14000/414113] Tokenized the captions.
# [15000/414113] Tokenized the captions.
# [16000/414113] Tokenized the captions.
# [17000/414113] Tokenized the captions.
# [18000/414113] Tokenized the captions.
# [19000/414113] Tokenized the captions.
# [20000/414113] Tokenized the captions.
# [21000/414113] Tokenized the captions.
# ...

# %%
# !python resize.py
# Out:
# [0/82783] Resized the images and saved into './data/resized2014/'.
# [100/82783] Resized the images and saved into './data/resized2014/'.
# [200/82783] Resized the images and saved into './data/resized2014/'.
# [300/82783] Resized the images and saved into './data/resized2014/'.
# [400/82783] Resized the images and saved into './data/resized2014/'.
# [500/82783] Resized the images and saved into './data/resized2014/'.
# [600/82783] Resized the images and saved into './data/resized2014/'.
# [700/82783] Resized the images and saved into './data/resized2014/'.
# [800/82783] Resized the images and saved into './data/resized2014/'.
# [900/82783] Resized the images and saved into './data/resized2014/'.
# [1000/82783] Resized the images and saved into './data/resized2014/'.
# [1100/82783] Resized the images and saved into './data/resized2014/'.
# [1200/82783] Resized the images and saved into './data/resized2014/'.
# [1300/82783] Resized the images and saved into './data/resized2014/'.
# ...

# %%
# !python train.py
# Out:
# Namespace(batch_size=128, caption_path='./data/annotations/captions_train2014.json', crop_size=224, embed_size=256, hidden_size=512, image_dir='./data/resized2014', learning_rate=0.001, log_step=50, model_path='./models/', num_epochs=2, num_layers=1, num_workers=2, save_step=100, vocab_path='./data/vocab.pkl')
# loading annotations into memory...
# Done (t=0.70s)
# creating index...
# index created!
# Epoch [0/2], Step [0/3236], Loss: 9.2038, Perplexity: 9934.5180
# Epoch [0/2], Step [50/3236], Loss: 4.6426, Perplexity: 103.8181
# Epoch [0/2], Step [100/3236], Loss: 4.1027, Perplexity: 60.5015
# Epoch [0/2], Step [150/3236], Loss: 3.6385, Perplexity: 38.0366
# Epoch [0/2], Step [200/3236], Loss: 3.6294, Perplexity: 37.6896
# Epoch [0/2], Step [250/3236], Loss: 3.5082, Perplexity: 33.3892
# Epoch [0/2], Step [300/3236], Loss: 3.3362, Perplexity: 28.1112
# Epoch [0/2], Step [350/3236], Loss: 3.2325, Perplexity: 25.3435
# Epoch [0/2], Step [400/3236], Loss: 3.1132, Perplexity: 22.4938
# ...

# %%
os.chdir("ImageCaption")
# !ls
# Out:
# build_vocab.py	data_loader.py	model.py  __pycache__  sample.py
# data		download.sh	models	  resize.py    train.py

# %%
# !mv train.py /content/ImageCaption/

# %%
os.chdir("..")
# !ls
# Out:
# ImageCaption  sample_data  sample.py

# %%
# !mkdir test

# %%
# !mv model.py /content/ImageCaption/

# %%
# !mv sample.py /content/ImageCaption/

# %%
# !mv ship.jpg /content/ImageCaption/test/

# %%
os.chdir("ImageCaption")

# %%
# !python resize.py --image_dir './test/' --output_dir './test/'
# Out:
# [0/1] Resized the images and saved into './test/'.
# [0/1] Resized the images and saved into './test/'.

# %%
# !python sample.py --image './test/ship.jpg'
# Out:
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/transforms.py:188: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.
#   "please use transforms.Resize instead.")
# <start> a small boat is floating on the water . <end>

# %%
# !mv 1.jpg /content/ImageCaption/test/
# !mv 2.jpg /content/ImageCaption/test/
os.chdir("ImageCaption")
# !ls
# !python resize.py --image_dir './test/' --output_dir './test/'
# Out:
# build_vocab.py	data_loader.py	model.py  __pycache__  sample.py  train.py
# data		download.sh	models	  resize.py    test
# [0/3] Resized the images and saved into './test/'.
# [0/3] Resized the images and saved into './test/'.

# %%
# !python sample.py --image './test/1.jpg'
# Out:
# <start> a cat is sitting on a table with a bowl of food . <end>

# %%
# !python sample.py --image './test/2.jpg'
# Out:
# <start> a red car parked on a street next to a car . <end>

# %%
# !ls
# Out:
# build_vocab.py	data_loader.py	model.py  __pycache__  sample.py  train.py
# data		download.sh	models	  resize.py    test

# %%
# !cd data

# %%
# !cd annotation
# Out:
# /bin/bash: line 0: cd: annotation: No such file or directory

# %%
# !cd data

# %%
# !cd annotations
# Out:
# /bin/bash: line 0: cd: annotations: No such file or directory

# %%
# !ls
# Out:
# build_vocab.py	data_loader.py	model.py  __pycache__  sample.py  train.py
# data		download.sh	models	  resize.py    test

# %%
os.chdir('data/annotations')
# !ls
# Out:
# captions_train2014.json  captions_val2014.json

# %%
os.chdir('../train2014')

# %%
from google.colab import files


files.download('COCO_train2014_000000133766.jpg')

# %%
from google.colab import files

with open('COCO_train2014_000000133767.jpg', 'w') as f:
  pass

files.download('COCO_train2014_000000133767.jpg')

# %%
# !mv COCO_train2014_000000133766.jpg /content/ImageCaption/

# %%
os.chdir('..')
# !ls
# Out:
# 3.jpg  ImageCaption  sample_data

# %%
# !ls
# Out:
# annotations  resized2014  train2014  val2014  vocab.pkl

# %%
# !mv 3.jpg /content/ImageCaption/test/

# %%
os.chdir('ImageCaption')
# !ls
# Out:
# build_vocab.py			 data_loader.py  models       sample.py
# COCO_train2014_000000133766.jpg  download.sh	 __pycache__  test
# data				 model.py	 resize.py    train.py

# %%
# !python sample.py --image './test/3.jpg'
# Out:
# <start> a man is holding a laptop and a laptop . <end>
